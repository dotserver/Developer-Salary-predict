# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('survey_results_public.csv')

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# 2                                 Russian Federation      NaN        NaN
# 3                                            Austria      NaN        NaN
# 4  United Kingdom of Great Britain and Northern I...      NaN    England
#
#                                              EdLevel     Age1stCode  \
# 0  Secondary school (e.g. American high school, G...  18 - 24 years
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
#
#                                            LearnCode YearsCode  ...  \
# 0  Coding Bootcamp;Other online resources (ex: vi...       NaN  ...
# 1  Other online resources (ex: videos, blogs, etc...         7  ...
# 2  Other online resources (ex: videos, blogs, etc...       NaN  ...
# 3                                                NaN       NaN  ...
# 4                            Friend or family member        17  ...
#
#                Age Gender Trans                Sexuality  \
# 0  25-34 years old    Man    No  Straight / Heterosexual
# 1  18-24 years old    Man    No  Straight / Heterosexual
# 2  18-24 years old    Man    No        Prefer not to say
# 3  35-44 years old    Man    No  Straight / Heterosexual
# 4  25-34 years old    Man    No                      NaN
#
#                       Ethnicity                Accessibility  \
# 0  White or of European descent            None of the above
# 1  White or of European descent            None of the above
# 2             Prefer not to say            None of the above
# 3  White or of European descent  I am deaf / hard of hearing
# 4  White or of European descent            None of the above
#
#         MentalHealth           SurveyLength                  SurveyEase  \
# 0  None of the above  Appropriate in length                        Easy
# 1  None of the above  Appropriate in length                        Easy
# 2  None of the above  Appropriate in length                        Easy
# 3                NaN  Appropriate in length  Neither easy nor difficult
# 4                NaN  Appropriate in length                        Easy
#
#   ConvertedCompYearly
# 0             62268.0
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 48 columns]

# %%
df = df[["Country", "EdLevel", "YearsCodePro", "Employment", "ConvertedCompYearly"]]
df = df.rename({"ConvertedCompYearly":"Salary"}, axis=1)
df.head()
# Out:
#                                              Country  \
# 0                                           Slovakia
# 1                                        Netherlands
# 2                                 Russian Federation
# 3                                            Austria
# 4  United Kingdom of Great Britain and Northern I...
#
#                                              EdLevel YearsCodePro  \
# 0  Secondary school (e.g. American high school, G...          NaN
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)          NaN
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)          NaN
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)          NaN
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)           10
#
#                                           Employment   Salary
# 0  Independent contractor, freelancer, or self-em...  62268.0
# 1                                 Student, full-time      NaN
# 2                                 Student, full-time      NaN
# 3                                 Employed full-time      NaN
# 4  Independent contractor, freelancer, or self-em...      NaN

# %%
df = df[df["Salary"].notnull()]
df.head()
# Out:
#      Country                                            EdLevel YearsCodePro  \
# 0   Slovakia  Secondary school (e.g. American high school, G...          NaN
# 9     Sweden    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)            4
# 11     Spain       Bachelor’s degree (B.A., B.S., B.Eng., etc.)            5
# 12   Germany    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)            6
# 16    Turkey       Bachelor’s degree (B.A., B.S., B.Eng., etc.)            2
#
#                                            Employment   Salary
# 0   Independent contractor, freelancer, or self-em...  62268.0
# 9                                  Employed full-time  51552.0
# 11                                 Employed full-time  46482.0
# 12                                 Employed full-time  77290.0
# 16                                 Employed full-time  17748.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46844 entries, 0 to 83438
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       46844 non-null  object
#  1   EdLevel       46823 non-null  object
#  2   YearsCodePro  46391 non-null  object
#  3   Employment    46831 non-null  object
#  4   Salary        46844 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 2.1+ MB

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Country         0
# EdLevel         0
# YearsCodePro    0
# Employment      0
# Salary          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46359 entries, 9 to 83438
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       46359 non-null  object
#  1   EdLevel       46359 non-null  object
#  2   YearsCodePro  46359 non-null  object
#  3   Employment    46359 non-null  object
#  4   Salary        46359 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 2.1+ MB

# %%
df = df[df["Employment"] == "Employed full-time"]
df = df.drop("Employment", axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40211 entries, 9 to 83438
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       40211 non-null  object
#  1   EdLevel       40211 non-null  object
#  2   YearsCodePro  40211 non-null  object
#  3   Salary        40211 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.5+ MB

# %%
df["Country"].value_counts()
# Out:
# Country
# United States of America                                9175
# India                                                   3385
# Germany                                                 2753
# United Kingdom of Great Britain and Northern Ireland    2604
# Canada                                                  1553
#                                                         ...
# Saint Kitts and Nevis                                      1
# Monaco                                                     1
# Libyan Arab Jamahiriya                                     1
# Somalia                                                    1
# Burundi                                                    1
# Name: count, Length: 166, dtype: int64

# %% [markdown]
# *It is noticed that there are some countries that has just one result, which will reduce the accuracy of the model. Intsead of dropping the rows with these country, they will added together as one called "others"*

# %%
def shorten_categories(categories,cutoff):
    categorical_map = {}
    for i in range(len(categories)):
        if categories.values[i] >= cutoff:
            categorical_map[categories.index[i]] = categories.index[i]
        else:
            categorical_map[categories.index[i]] = 'Other'
    return categorical_map

# %%
country_map = shorten_categories(df.Country.value_counts(), 400)
df['Country'] = df['Country'].map(country_map)
# .map() was used to pass the function on df['Country']
df.Country.value_counts()
# Out:
# Country
# Other                                                   10725
# United States of America                                 9175
# India                                                    3385
# Germany                                                  2753
# United Kingdom of Great Britain and Northern Ireland     2604
# Canada                                                   1553
# France                                                   1396
# Brazil                                                   1340
# Spain                                                     890
# Netherlands                                               835
# Australia                                                 825
# Poland                                                    775
# Italy                                                     756
# Russian Federation                                        741
# Sweden                                                    735
# Turkey                                                    458
# Switzerland                                               438
# Israel                                                    425
# Norway                                                    402
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(1,1, figsize=(20, 12))
df.boxplot('Salary', 'Country', ax=ax)
plt.suptitle('Salary (US$) v Country')
plt.title('')
plt.ylabel('Salary')
plt.xticks(rotation=90)
plt.show()

# %%
df = df[df['Salary'] <= 300000]
df = df[df['Salary'] >= 10000]
df = df[df['Country'] != 'Other']

# %%
fig, ax = plt.subplots(1,1, figsize=(12, 7))
df.boxplot('Salary', 'Country', ax=ax)
plt.suptitle('Salary (US$) v Country')
plt.title('')
plt.ylabel('Salary')
plt.xticks(rotation=90)
plt.show()

# %%
df["YearsCodePro"].unique()
# .unique() to categorize the column "YearsCodePro"
# Out:
# array(['4', '5', '6', '2', '18', '21', '16', '10', 'Less than 1 year',
#        '15', '3', '12', '8', '17', '1', '14', '26', '34', '11', '25',
#        '24', '22', '13', '9', '7', '39', '20', '27', '23', '35', '30',
#        '19', '33', '37', '43', '40', '29', '38', '31', '42', '28', '46',
#        '32', '36', '47', '45', '44', '41', 'More than 50 years', '50',
#        '49', '48'], dtype=object)

# %%
def clean_experience(x):
    if x ==  'More than 50 years':
        return 50
    if x == 'Less than 1 year':
        return 0.5
    return float(x)

df['YearsCodePro'] = df['YearsCodePro'].apply(clean_experience)

# %%
df["EdLevel"].unique()
# .unique() to categorize the column "EdLevel"
# Out:
# array(['Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#        'Some college/university study without earning a degree',
#        'Professional degree (JD, MD, etc.)',
#        'Other doctoral degree (Ph.D., Ed.D., etc.)', 'Something else',
#        'Primary/elementary school', 'Associate degree (A.A., A.S., etc.)',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)'],
#       dtype=object)

# %%
def clean_education(x):
    if 'Bachelor’s degree' in x:
        return 'Bachelor’s degree'
    if 'Master’s degree' in x:
        return 'Master’s degree'
    if 'Professional degree' in x or 'Other doctoral' in x:
        return 'Post grad'
    return 'Less than a Bachelors'

df['EdLevel'] = df['EdLevel'].apply(clean_education)

# %%
df["EdLevel"].unique()
# Out:
# array(['Master’s degree', 'Bachelor’s degree', 'Less than a Bachelors',
#        'Post grad'], dtype=object)

# %% [markdown]
# ### One hot encoding to convert categorical data to number

# %%
! pip install scikit-learn==1.4.1.post1
# Out:
# Requirement already satisfied: scikit-learn==1.4.1.post1 in ./.venv/lib/python3.9/site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in ./.venv/lib/python3.9/site-packages (from scikit-learn==1.4.1.post1) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn==1.4.1.post1) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn==1.4.1.post1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn==1.4.1.post1) (3.4.0)

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

# %%
le_education = LabelEncoder()
df['EdLevel'] = le_education.fit_transform(df['EdLevel'])
df["EdLevel"].unique()
#le.classes_
# Out:
# array([2, 0, 1, 3])

# %%
sklearn.__version__
# Out:
# '1.4.1.post1'

# %%
le_country = LabelEncoder()
df['Country'] = le_country.fit_transform(df['Country'])
df["Country"].unique()
# Out:
# array([13, 12,  4, 15,  2,  3, 14, 16, 11,  6, 17,  1,  7,  8, 10,  0,  5,
#         9])

# %%
X = df.drop("Salary", axis=1)
y = df["Salary"]

# %%
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()
linear_reg.fit(X, y.values)
# Out:
# LinearRegression()

# %%
y_pred = linear_reg.predict(X)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
error = np.sqrt(mean_squared_error(y, y_pred))

# %%
error
# Out:
# 45297.38442408917

# %%
from sklearn.tree import DecisionTreeRegressor
dec_tree_reg = DecisionTreeRegressor(random_state=0)
dec_tree_reg.fit(X, y.values)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = dec_tree_reg.predict(X)

# %%
error = np.sqrt(mean_squared_error(y, y_pred))
print("${:,.02f}".format(error))
# Out:
# $34,950.48

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_reg = RandomForestRegressor(random_state=0)
random_forest_reg.fit(X, y.values)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = random_forest_reg.predict(X)

# %%
error = np.sqrt(mean_squared_error(y, y_pred))
print("${:,.02f}".format(error))
# Out:
# $35,025.34

# %%
from sklearn.model_selection import GridSearchCV

max_depth = [None, 2,4,6,8,10,12]
parameters = {"max_depth": max_depth}

regressor = RandomForestRegressor(random_state=0)
gs = GridSearchCV(regressor, parameters, scoring='neg_mean_squared_error')
gs.fit(X, y.values)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(random_state=0),
#              param_grid={'max_depth': [None, 2, 4, 6, 8, 10, 12]},
#              scoring='neg_mean_squared_error')

# %%
regressor = gs.best_estimator_

regressor.fit(X, y.values)
y_pred = regressor.predict(X)
error = np.sqrt(mean_squared_error(y, y_pred))
print("${:,.02f}".format(error))
# Out:
# $35,690.47

# %%
X
# Out:
#        Country  EdLevel  YearsCodePro
# 9           13        2           4.0
# 11          12        0           5.0
# 12           4        2           6.0
# 16          15        0           2.0
# 17           2        0           6.0
# ...        ...      ...           ...
# 83430       17        2          21.0
# 83432        2        0           0.5
# 83434       17        0           5.0
# 83436       17        1           4.0
# 83438        1        3           4.0
#
# [26505 rows x 3 columns]

# %% [markdown]
# ### Applying the developed model on a random input

# %%
# country, edlevel, yearscode
X_test = np.array([["United States of America", 'Bachelor’s degree', 15 ]])
X_test
# Out:
# array([['United States of America', 'Bachelor’s degree', '15']],
#       dtype='<U24')

# %%
X_test[:, 0]
# Out:
# array(['United States of America'], dtype='<U24')

# %%
X_test[:, 0] = le_country.transform(X_test[:, 0])
X_test[:, 1] = le_education.transform(X_test[:, 1])
X_test = X_test.astype(float)
X
# Out:
# array([[17.,  2., 15.]])

# %%
y_pred = regressor.predict(X_test)
y_pred
#the prediction of the salary of the random input according to the regressor model
# Out:
# /Users/tobi/Documents/Developer-Salary-predict/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([148442.14099832])

# %% [markdown]
# ### Saving the regressor model

# %%
import pickle

# %%
data = {"model": regressor, "le_country": le_country, "le_education": le_education}
with open('saved_steps.pkl', 'wb') as file:
    pickle.dump(data, file)

# %%
with open('saved_steps.pkl', 'rb') as file:
    data = pickle.load(file)

regressor_loaded = data["model"]
le_country = data["le_country"]
le_education = data["le_education"]

# %%
y_pred = regressor_loaded.predict(X_test)
y_pred
# Out:
# /Users/tobi/Documents/Developer-Salary-predict/.venv/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([148442.14099832])
